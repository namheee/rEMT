# %% [markdown]
# # Main 1 - EMT network analysis
#
# Please refer to the Method section.

# %%
import numpy as np
import pandas as pd
import itertools
import networkx as nx
import copy
import os

from pyboolnet.file_exchange import bnet2primes, primes2bnet
from pyboolnet.interaction_graphs import primes2igraph
from pyboolnet.state_transition_graphs import primes2stg
from pyboolnet.attractors import compute_attractors_tarjan

from modules.attractorSim import rand_initial_states, compute_attractor_from_primes, compute_phenotype, Simulation
from modules.stability import compute_networkStability

# %%
network_dir = './network/'
model_file = network_dir + 'EMT_Network.bnet'
primes = bnet2primes(model_file)
nodeList = list(primes.keys())
graph = primes2igraph(primes)
update_mode = "synchronous"
   

phenotype = {'E':{'Ecadherin':1, 'ZEB1':0}, 'M':{'Ecadherin':0, 'ZEB1':1}, 'H1':{'Ecadherin':1, 'ZEB1':1}, 'H2':{'Ecadherin':0, 'ZEB1':0}}
phenotypeAnnot = {'E':-1,'M':1, 'H1':0, 'H2':0}
markers = ['Ecadherin','miR200','miR34','Snail','Twist1','ZEB1','EpCAM','THY1','MYC']


if 2**len(nodeList) >= 100000: num_init = 100000
else:  num_init = 2**len(nodeList)
initState = rand_initial_states(num_init, len(nodeList))

# %% [markdown]
# ### Perturbation analysis

# %%
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
from collections import defaultdict


def phenotypeAnnot_diff(x):
    if x>=0.5: return (-1)
    elif x<(-0.5): return (1)
    else: return (0)

def perturb_analysis(perturb_p, perturb_s, save_perturbname):
    perturb_p.loc[:,'Desired1'] = [1,1,1,0,0,0,1,0,0] #rEMT
    perturb_p.loc[:,'Desired2'] = [1,1,1,0,0,0,0,0,0] #chemosensitive rEMT
        
    dT1 = perturb_p.loc[:,sorted(set(perturb_p.columns)-set(['Desired2']))]
    didx1 = list(dT1.columns).index('Desired1')
    dc_T1_ = cosine_similarity(dT1.T)
    dT1.loc['cosineSim1',:] = dc_T1_[didx1,:]
    
    dT2 = perturb_p.loc[:,sorted(set(perturb_p.columns)-set(['Desired1']))]
    didx2 = list(dT2.columns).index('Desired2')
    dc_T2_ = cosine_similarity(dT2.T)
    dT2.loc['cosineSim2',:] = dc_T2_[didx2,:]
    
    dT3 = pd.concat([dT1.loc['cosineSim1',:], dT2.loc['cosineSim2',:]], axis=1, sort=True).T
    perturb_p.loc['cosineSim1',:] = dT3.loc['cosineSim1',perturb_p.columns]
    perturb_p.loc['cosineSim2',:] = dT3.loc['cosineSim2',perturb_p.columns]
    perturb_p = perturb_p.fillna(0)
    perturb_p.loc['Diff',:] =  perturb_p.loc['Ecadherin',:] -  perturb_p.loc['ZEB1',:]
    perturb_p.loc['Diff_pheno',:] = [phenotypeAnnot_diff(x) for x in (perturb_p.loc['Ecadherin',:] -  perturb_p.loc['ZEB1',:]).values]    
    
    ## new rEMT score
    perturb_p.loc['weight',:] = (perturb_p.loc['Diff',:] + 1)/2
    perturb_p.loc['rEMTscore',:] = perturb_p.loc['cosineSim1',:].values * perturb_p.loc['weight',:].values
    perturb_p.loc['chemo_rEMTscore',:] = perturb_p.loc['cosineSim2',:].values * perturb_p.loc['weight',:].values
    
    # save result
    perturb_result = pd.concat([perturb_p, perturb_s], sort=True).T        
    perturb_result.to_csv(save_perturbname)    
    
    
def perturbAnalysis(allperturbs, fix_dict, save_dir, save_perturbname):
    perturb_p = pd.DataFrame([])
    perturb_s = pd.DataFrame([])
    for perturb in allperturbs:
        fix_dict_tmp = copy.deepcopy(fix_dict)
        fix_dict_tmp.update(perturb)
        print(fix_dict_tmp)
        primes_new, pheno_df, att_ave_pd, attrs_dict = Simulation(fix_dict_tmp, primes, update_mode, initState, phenotype, phenotypeAnnot)
        dT = pd.DataFrame([0 for _ in markers], index = markers, columns = [str(list(perturb.items()))])
        dT.loc[markers,:] = att_ave_pd.loc[markers,:].values
        perturb_p = pd.concat([perturb_p,dT],axis=1, sort=True)     
    
        dS = pd.DataFrame.from_dict(compute_networkStability(attrs_dict, graph, nodeList)[1],orient='index', columns = [str(list(perturb.items()))] )
        perturb_s = pd.concat([perturb_s,dS],axis=1, sort=True)     
    perturb_analysis(perturb_p, perturb_s, save_perturbname)

# %%
fix_dict = {'TGFb':1,'RAS':1}
save_dir = './Result/TGFON/' 
if save_dir.split('/')[1] not in os.listdir(): os.mkdir(save_dir)
save_perturbname = save_dir + 'TGFON_single_simul_result.csv'
allsingles = [{n:1} for n in nodeList] + [{n:0} for n in nodeList]

perturbAnalysis(allsingles, fix_dict, save_dir, save_perturbname)
# Out:
# {'TGFb': 1, 'RAS': 1, 'AKT': 1}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 13.249711513519287
#            Ratio
# phenotype
# M            1.0
# {'TGFb': 1, 'RAS': 1, 'AP1': 1}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 12.210749626159668
#            Ratio
# phenotype
# M            1.0
# {'TGFb': 1, 'RAS': 1, 'ERK': 1}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 12.402827739715576
#            Ratio
# phenotype
# M            1.0
# {'TGFb': 1, 'RAS': 1, 'Ecadherin': 1}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 13.02165174484253
#            Ratio
# phenotype
# H1           1.0
# {'TGFb': 1, 'RAS': 1, 'EpCAM': 1}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 12.279854536056519
#            Ratio
# phenotype
# M            1.0
# {'TGFb': 1, 'RAS': 1, 'GLI': 1}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 13.757991552352905
#            Ratio
# phenotype
# M            1.0
# {'TGFb': 1, 'RAS': 1, 'GRB2SOS': 1}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 13.608627080917358
#            Ratio
# phenotype
# M            1.0
# {'TGFb': 1, 'RAS': 1, 'GSK3b': 1}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 12.729054927825928
#            Ratio
# phenotype
# M            1.0
# {'TGFb': 1, 'RAS': 1, 'IKK': 1}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 12.628550052642822
#            Ratio
# phenotype
# M            1.0
# {'TGFb': 1, 'RAS': 1, 'MDM2': 1}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 13.199341297149658
#            Ratio
# phenotype
# M            1.0
# {'TGFb': 1, 'RAS': 1, 'MEK': 1}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 12.791807651519775
#            Ratio
# phenotype
# M            1.0
# {'TGFb': 1, 'RAS': 1, 'MYC': 1}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 13.35152268409729
#            Ratio
# phenotype
# M            1.0
# {'TGFb': 1, 'RAS': 1, 'NFKB': 1}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 12.308248519897461
#            Ratio
# phenotype
# M            1.0
# {'TGFb': 1, 'RAS': 1, 'NOTCH': 1}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 12.787577867507935
#            Ratio
# phenotype
# M            1.0
# {'TGFb': 1, 'RAS': 1, 'PI3K': 1}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 13.102673530578613
#            Ratio
# phenotype
# M            1.0
# {'TGFb': 1, 'RAS': 1, 'RAF': 1}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 12.745268106460571
#            Ratio
# phenotype
# M            1.0
# {'TGFb': 1, 'RAS': 1}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 13.928148984909058
#            Ratio
# phenotype
# M            1.0
# {'TGFb': 1, 'RAS': 1, 'SMAD23': 1}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 13.855069160461426
#            Ratio
# phenotype
# M            1.0
# {'TGFb': 1, 'RAS': 1, 'SMAD4': 1}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 13.305353164672852
#            Ratio
# phenotype
# M            1.0
# {'TGFb': 1, 'RAS': 1, 'Snail': 1}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 12.853066682815552
#            Ratio
# phenotype
# M            1.0
# {'TGFb': 1, 'RAS': 1, 'TAK1': 1}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 13.753108739852905
#            Ratio
# phenotype
# M            1.0
# {'TGFb': 1, 'RAS': 1, 'TGFBR': 1}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 12.796939611434937
#            Ratio
# phenotype
# M            1.0
# {'TGFb': 1, 'RAS': 1}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 13.777316570281982
#            Ratio
# phenotype
# M            1.0
# {'TGFb': 1, 'RAS': 1, 'THY1': 1}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 13.105978965759277
#            Ratio
# phenotype
# M            1.0
# {'TGFb': 1, 'RAS': 1, 'Twist1': 1}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 13.232167720794678
#            Ratio
# phenotype
# M            1.0
# {'TGFb': 1, 'RAS': 1, 'ZEB1': 1}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 12.068422079086304
#            Ratio
# phenotype
# M            1.0
# {'TGFb': 1, 'RAS': 1, 'bcatenin': 1}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 12.033892154693604
#            Ratio
# phenotype
# M            1.0
# {'TGFb': 1, 'RAS': 1, 'miR200': 1}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 12.981740713119507
#            Ratio
# phenotype
# H1           1.0
# {'TGFb': 1, 'RAS': 1, 'miR34': 1}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 12.59684419631958
#            Ratio
# phenotype
# M            1.0
# {'TGFb': 1, 'RAS': 1, 'p38': 1}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 12.950551986694336
#            Ratio
# phenotype
# M            1.0
# {'TGFb': 1, 'RAS': 1, 'p53': 1}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 14.44948434829712
#               Ratio
# phenotype
# H1         0.562916
# M          0.437084
# {'TGFb': 1, 'RAS': 1, 'AKT': 0}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 12.86653208732605
#            Ratio
# phenotype
# M            1.0
# {'TGFb': 1, 'RAS': 1, 'AP1': 0}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 12.285206079483032
#            Ratio
# phenotype
# M            1.0
# {'TGFb': 1, 'RAS': 1, 'ERK': 0}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 14.874494314193726
#            Ratio
# phenotype
# M            1.0
# {'TGFb': 1, 'RAS': 1, 'Ecadherin': 0}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 13.219485759735107
#            Ratio
# phenotype
# M            1.0
# {'TGFb': 1, 'RAS': 1, 'EpCAM': 0}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 11.960917949676514
#            Ratio
# phenotype
# M            1.0
# {'TGFb': 1, 'RAS': 1, 'GLI': 0}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 13.663995027542114
#            Ratio
# phenotype
# M            1.0
# {'TGFb': 1, 'RAS': 1, 'GRB2SOS': 0}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 13.370595216751099
#            Ratio
# phenotype
# M            1.0
# {'TGFb': 1, 'RAS': 1, 'GSK3b': 0}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 13.286023378372192
#            Ratio
# phenotype
# M            1.0
# {'TGFb': 1, 'RAS': 1, 'IKK': 0}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 12.794644594192505
#            Ratio
# phenotype
# M            1.0
# {'TGFb': 1, 'RAS': 1, 'MDM2': 0}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 15.87142014503479
#              Ratio
# phenotype
# H1         0.33792
# M          0.66208
# {'TGFb': 1, 'RAS': 1, 'MEK': 0}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 15.39893126487732
#            Ratio
# phenotype
# M            1.0
# {'TGFb': 1, 'RAS': 1, 'MYC': 0}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 13.244690656661987
#            Ratio
# phenotype
# M            1.0
# {'TGFb': 1, 'RAS': 1, 'NFKB': 0}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 12.639510869979858
#            Ratio
# phenotype
# M            1.0
# {'TGFb': 1, 'RAS': 1, 'NOTCH': 0}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 14.052576780319214
#            Ratio
# phenotype
# M            1.0
# {'TGFb': 1, 'RAS': 1, 'PI3K': 0}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 12.871768474578857
#            Ratio
# phenotype
# M            1.0
# {'TGFb': 1, 'RAS': 1, 'RAF': 0}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 13.690149545669556
#            Ratio
# phenotype
# M            1.0
# {'TGFb': 1, 'RAS': 0}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 13.385841369628906
#            Ratio
# phenotype
# M            1.0
# {'TGFb': 1, 'RAS': 1, 'SMAD23': 0}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 13.352029085159302
#            Ratio
# phenotype
# M            1.0
# {'TGFb': 1, 'RAS': 1, 'SMAD4': 0}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 17.78061079978943
#               Ratio
# phenotype
# H1         0.864511
# M          0.135489
# {'TGFb': 1, 'RAS': 1, 'Snail': 0}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 12.145970821380615
#            Ratio
# phenotype
# H1           1.0
# {'TGFb': 1, 'RAS': 1, 'TAK1': 0}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 13.227769613265991
#            Ratio
# phenotype
# M            1.0
# {'TGFb': 1, 'RAS': 1, 'TGFBR': 0}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 16.597798109054565
#               Ratio
# phenotype
# E          0.009502
# M          0.990498
# {'TGFb': 0, 'RAS': 1}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 16.40509581565857
#               Ratio
# phenotype
# E          0.013396
# H1         0.986604
# {'TGFb': 1, 'RAS': 1, 'THY1': 0}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 13.310219764709473
#            Ratio
# phenotype
# M            1.0
# {'TGFb': 1, 'RAS': 1, 'Twist1': 0}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 13.70681381225586
#            Ratio
# phenotype
# M            1.0
# {'TGFb': 1, 'RAS': 1, 'ZEB1': 0}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 12.031202793121338
#            Ratio
# phenotype
# H1           1.0
# {'TGFb': 1, 'RAS': 1, 'bcatenin': 0}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 12.339755296707153
#            Ratio
# phenotype
# M            1.0
# {'TGFb': 1, 'RAS': 1, 'miR200': 0}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 13.544859886169434
#            Ratio
# phenotype
# M            1.0
# {'TGFb': 1, 'RAS': 1, 'miR34': 0}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 13.337838649749756
#            Ratio
# phenotype
# M            1.0
# {'TGFb': 1, 'RAS': 1, 'p38': 0}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 13.027932405471802
#            Ratio
# phenotype
# M            1.0
# {'TGFb': 1, 'RAS': 1, 'p53': 0}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 12.066298007965088
#            Ratio
# phenotype
# M            1.0

# %% [markdown]
# ### Molecular state ambiguity

# %%
from modules.frustration import computeFusingT_updated

fix_dict = {'TGFb':1,'RAS':1}
ctrl = {'TGFb':1,'RAS':1}
save_dir = './Result/TGFON/' 
computeFusingT_updated(allsingles, fix_dict, ctrl, primes, model_file, save_dir+'TGFON_single')
