# %% [markdown]
# # Main 1 - EMT network analysis
#
# Please refer to the Method section.

# %%
import numpy as np
import pandas as pd
import itertools
import networkx as nx
import copy
import os

from pyboolnet.file_exchange import bnet2primes, primes2bnet
from pyboolnet.interaction_graphs import primes2igraph
from pyboolnet.state_transition_graphs import primes2stg
from pyboolnet.attractors import compute_attractors_tarjan

from modules.attractorSim import rand_initial_states, compute_attractor_from_primes, compute_phenotype, Simulation
from modules.stability import compute_networkStability

# %%
network_dir = './network/'
model_file = network_dir + 'EMT_Network.bnet'
primes = bnet2primes(model_file)
nodeList = list(primes.keys())
graph = primes2igraph(primes)
update_mode = "synchronous"
   

phenotype = {'E':{'Ecadherin':1, 'ZEB1':0}, 'M':{'Ecadherin':0, 'ZEB1':1}, 'H1':{'Ecadherin':1, 'ZEB1':1}, 'H2':{'Ecadherin':0, 'ZEB1':0}}
phenotypeAnnot = {'E':-1,'M':1, 'H1':0, 'H2':0}
markers = ['Ecadherin','miR200','miR34','Snail','Twist1','ZEB1','EpCAM','THY1','MYC']


if 2**len(nodeList) >= 100000: num_init = 100000
else:  num_init = 2**len(nodeList)
initState = rand_initial_states(num_init, len(nodeList))

# %% [markdown]
# ### Perturbation analysis

# %%
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
from collections import defaultdict


def phenotypeAnnot_diff(x):
    if x>=0.5: return (-1)
    elif x<(-0.5): return (1)
    else: return (0)

def perturb_analysis(perturb_p, perturb_s, save_perturbname):
    perturb_p.loc[:,'Desired1'] = [1,1,1,0,0,0,1,0,0] #rEMT
    perturb_p.loc[:,'Desired2'] = [1,1,1,0,0,0,0,0,0] #chemosensitive rEMT
        
    dT1 = perturb_p.loc[:,sorted(set(perturb_p.columns)-set(['Desired2']))]
    didx1 = list(dT1.columns).index('Desired1')
    dc_T1_ = cosine_similarity(dT1.T)
    dT1.loc['cosineSim1',:] = dc_T1_[didx1,:]
    
    dT2 = perturb_p.loc[:,sorted(set(perturb_p.columns)-set(['Desired1']))]
    didx2 = list(dT2.columns).index('Desired2')
    dc_T2_ = cosine_similarity(dT2.T)
    dT2.loc['cosineSim2',:] = dc_T2_[didx2,:]
    
    dT3 = pd.concat([dT1.loc['cosineSim1',:], dT2.loc['cosineSim2',:]], axis=1, sort=True).T
    perturb_p.loc['cosineSim1',:] = dT3.loc['cosineSim1',perturb_p.columns]
    perturb_p.loc['cosineSim2',:] = dT3.loc['cosineSim2',perturb_p.columns]
    perturb_p = perturb_p.fillna(0)
    perturb_p.loc['Diff',:] =  perturb_p.loc['Ecadherin',:] -  perturb_p.loc['ZEB1',:]
    perturb_p.loc['Diff_pheno',:] = [phenotypeAnnot_diff(x) for x in (perturb_p.loc['Ecadherin',:] -  perturb_p.loc['ZEB1',:]).values]    
    
    ## rEMT score
    perturb_p.loc['weight',:] = (perturb_p.loc['Diff',:] + 1)/2
    perturb_p.loc['rEMTscore',:] = perturb_p.loc['cosineSim1',:].values * perturb_p.loc['weight',:].values
    perturb_p.loc['chemo_rEMTscore',:] = perturb_p.loc['cosineSim2',:].values * perturb_p.loc['weight',:].values
    
    # save result
    perturb_result = pd.concat([perturb_p, perturb_s], sort=True).T        
    perturb_result.to_csv(save_perturbname)    
    
    
def perturbAnalysis(allperturbs, fix_dict, save_dir, save_perturbname):
    perturb_p = pd.DataFrame([])
    perturb_s = pd.DataFrame([])
    for perturb in allperturbs:
        fix_dict_tmp = copy.deepcopy(fix_dict)
        fix_dict_tmp.update(perturb)
        print(fix_dict_tmp)
        primes_new, pheno_df, att_ave_pd, attrs_dict = Simulation(fix_dict_tmp, primes, update_mode, initState, phenotype, phenotypeAnnot)
        dT = pd.DataFrame([0 for _ in markers], index = markers, columns = [str(list(perturb.items()))])
        dT.loc[markers,:] = att_ave_pd.loc[markers,:].values
        perturb_p = pd.concat([perturb_p,dT],axis=1, sort=True)     
    
        dS = pd.DataFrame.from_dict(compute_networkStability(attrs_dict, graph, nodeList)[1],orient='index', columns = [str(list(perturb.items()))] )
        perturb_s = pd.concat([perturb_s,dS],axis=1, sort=True)     
    perturb_analysis(perturb_p, perturb_s, save_perturbname)

# %%
fix_dict = {'TGFb':0,'RAS':1}
save_dir = './result/TGFOFF/' 
if save_dir not in os.listdir(): os.mkdir(save_dir)
save_perturbname = save_dir + 'TGFOFF_single_simul_result.csv'
allsingles = [{n:1} for n in nodeList] + [{n:0} for n in nodeList]

perturbAnalysis(allsingles, fix_dict, save_dir, save_perturbname)
# Out:
# {'TGFb': 0, 'RAS': 1, 'AKT': 1}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 15.326167106628418
#               Ratio
# phenotype
# E          0.010996
# H1         0.989004
# {'TGFb': 0, 'RAS': 1, 'AP1': 1}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 15.028164148330688
#               Ratio
# phenotype
# E          0.014136
# M          0.985864
# {'TGFb': 0, 'RAS': 1, 'ERK': 1}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 13.609905242919922
#              Ratio
# phenotype
# H1         0.93911
# M          0.06089
# {'TGFb': 0, 'RAS': 1, 'Ecadherin': 1}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 15.218493223190308
#              Ratio
# phenotype
# E          0.01372
# H1         0.98628
# {'TGFb': 0, 'RAS': 1, 'EpCAM': 1}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 14.874860525131226
#              Ratio
# phenotype
# E          0.01376
# H1         0.98624
# {'TGFb': 0, 'RAS': 1, 'GLI': 1}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 16.803144931793213
#               Ratio
# phenotype
# E          0.011638
# M          0.988362
# {'TGFb': 0, 'RAS': 1, 'GRB2SOS': 1}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 16.943212270736694
#               Ratio
# phenotype
# E          0.013687
# H1         0.986313
# {'TGFb': 0, 'RAS': 1, 'GSK3b': 1}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 14.512054204940796
#               Ratio
# phenotype
# E          0.732933
# H1         0.267067
# {'TGFb': 0, 'RAS': 1, 'IKK': 1}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 15.44705867767334
#               Ratio
# phenotype
# E          0.013816
# H1         0.986184
# {'TGFb': 0, 'RAS': 1, 'MDM2': 1}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 19.514822959899902
#               Ratio
# phenotype
# E          0.013535
# H1         0.986465
# {'TGFb': 0, 'RAS': 1, 'MEK': 1}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 16.539474487304688
#               Ratio
# phenotype
# E          0.010009
# H1         0.924012
# M          0.065979
# {'TGFb': 0, 'RAS': 1, 'MYC': 1}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 15.64258885383606
#               Ratio
# phenotype
# E          0.013082
# H1         0.986918
# {'TGFb': 0, 'RAS': 1, 'NFKB': 1}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 14.960224866867065
#               Ratio
# phenotype
# E          0.013254
# H1         0.986746
# {'TGFb': 0, 'RAS': 1, 'NOTCH': 1}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 13.685028076171875
#            Ratio
# phenotype
# M            1.0
# {'TGFb': 0, 'RAS': 1, 'PI3K': 1}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 15.590218305587769
#               Ratio
# phenotype
# E          0.012203
# H1         0.987797
# {'TGFb': 0, 'RAS': 1, 'RAF': 1}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 16.900225162506104
#               Ratio
# phenotype
# E          0.011291
# H1         0.924338
# M          0.064371
# {'TGFb': 0, 'RAS': 1}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 16.42482328414917
#               Ratio
# phenotype
# E          0.013662
# H1         0.986338
# {'TGFb': 0, 'RAS': 1, 'SMAD23': 1}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 13.340848922729492
#            Ratio
# phenotype
# M            1.0
# {'TGFb': 0, 'RAS': 1, 'SMAD4': 1}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 13.6310396194458
#            Ratio
# phenotype
# M            1.0
# {'TGFb': 0, 'RAS': 1, 'Snail': 1}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 14.256503582000732
#            Ratio
# phenotype
# M            1.0
# {'TGFb': 0, 'RAS': 1, 'TAK1': 1}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 16.533963203430176
#               Ratio
# phenotype
# E          0.013987
# H1         0.986013
# {'TGFb': 0, 'RAS': 1, 'TGFBR': 1}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 12.543551921844482
#            Ratio
# phenotype
# M            1.0
# {'TGFb': 1, 'RAS': 1}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 13.618102788925171
#            Ratio
# phenotype
# M            1.0
# {'TGFb': 0, 'RAS': 1, 'THY1': 1}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 15.434200286865234
#               Ratio
# phenotype
# E          0.013465
# H1         0.986535
# {'TGFb': 0, 'RAS': 1, 'Twist1': 1}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 15.74882459640503
#               Ratio
# phenotype
# E          0.013682
# H1         0.986318
# {'TGFb': 0, 'RAS': 1, 'ZEB1': 1}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 14.85226035118103
#            Ratio
# phenotype
# H1           1.0
# {'TGFb': 0, 'RAS': 1, 'bcatenin': 1}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 13.388036012649536
#            Ratio
# phenotype
# H1           1.0
# {'TGFb': 0, 'RAS': 1, 'miR200': 1}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 15.198419094085693
#            Ratio
# phenotype
# E            1.0
# {'TGFb': 0, 'RAS': 1, 'miR34': 1}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 14.292861700057983
#               Ratio
# phenotype
# E          0.013141
# H1         0.986859
# {'TGFb': 0, 'RAS': 1, 'p38': 1}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 16.130287408828735
#               Ratio
# phenotype
# E          0.013879
# H1         0.986121
# {'TGFb': 0, 'RAS': 1, 'p53': 1}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 16.270042419433594
#            Ratio
# phenotype
# E            1.0
# {'TGFb': 0, 'RAS': 1, 'AKT': 0}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 19.47661256790161
#               Ratio
# phenotype
# E          0.094347
# H1         0.905653
# {'TGFb': 0, 'RAS': 1, 'AP1': 0}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 14.79959225654602
#               Ratio
# phenotype
# E          0.013865
# H1         0.986135
# {'TGFb': 0, 'RAS': 1, 'ERK': 0}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 17.05735421180725
#               Ratio
# phenotype
# E          0.712518
# H1         0.287482
# {'TGFb': 0, 'RAS': 1, 'Ecadherin': 0}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 15.148959159851074
#              Ratio
# phenotype
# H1         0.01372
# M          0.98628
# {'TGFb': 0, 'RAS': 1, 'EpCAM': 0}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 14.77955436706543
#               Ratio
# phenotype
# E          0.013776
# H1         0.986224
# {'TGFb': 0, 'RAS': 1, 'GLI': 0}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 15.678849935531616
#               Ratio
# phenotype
# E          0.014306
# H1         0.985694
# {'TGFb': 0, 'RAS': 1, 'GRB2SOS': 0}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 16.143150329589844
#               Ratio
# phenotype
# E          0.013655
# H1         0.986345
# {'TGFb': 0, 'RAS': 1, 'GSK3b': 0}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 12.651963233947754
#            Ratio
# phenotype
# H1           1.0
# {'TGFb': 0, 'RAS': 1, 'IKK': 0}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 14.807586193084717
#               Ratio
# phenotype
# E          0.013809
# H1         0.986191
# {'TGFb': 0, 'RAS': 1, 'MDM2': 0}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 18.02459979057312
#            Ratio
# phenotype
# E            1.0
# {'TGFb': 0, 'RAS': 1, 'MEK': 0}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 17.370277881622314
#               Ratio
# phenotype
# E          0.570073
# H1         0.429927
# {'TGFb': 0, 'RAS': 1, 'MYC': 0}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 15.148497343063354
#               Ratio
# phenotype
# E          0.013083
# H1         0.986917
# {'TGFb': 0, 'RAS': 1, 'NFKB': 0}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 15.204373598098755
#               Ratio
# phenotype
# E          0.013195
# H1         0.986805
# {'TGFb': 0, 'RAS': 1, 'NOTCH': 0}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 15.595076322555542
#               Ratio
# phenotype
# E          0.013702
# H1         0.986298
# {'TGFb': 0, 'RAS': 1, 'PI3K': 0}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 15.800204277038574
#               Ratio
# phenotype
# E          0.015323
# H1         0.984677
# {'TGFb': 0, 'RAS': 1, 'RAF': 0}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 17.59858202934265
#               Ratio
# phenotype
# E          0.022222
# H1         0.977778
# {'TGFb': 0, 'RAS': 0}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 13.2638418674469
#            Ratio
# phenotype
# E            1.0
# {'TGFb': 0, 'RAS': 1, 'SMAD23': 0}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 15.585587501525879
#               Ratio
# phenotype
# E          0.026341
# H1         0.973659
# {'TGFb': 0, 'RAS': 1, 'SMAD4': 0}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 15.892975330352783
#               Ratio
# phenotype
# E          0.273149
# H1         0.726851
# {'TGFb': 0, 'RAS': 1, 'Snail': 0}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 14.473803281784058
#               Ratio
# phenotype
# E          0.013215
# H1         0.986785
# {'TGFb': 0, 'RAS': 1, 'TAK1': 0}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 15.580121755599976
#               Ratio
# phenotype
# E          0.013838
# H1         0.986162
# {'TGFb': 0, 'RAS': 1, 'TGFBR': 0}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 16.06146764755249
#               Ratio
# phenotype
# E          0.019509
# H1         0.980491
# {'TGFb': 0, 'RAS': 1}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 16.131032466888428
#               Ratio
# phenotype
# E          0.013662
# H1         0.986338
# {'TGFb': 0, 'RAS': 1, 'THY1': 0}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 15.991374731063843
#               Ratio
# phenotype
# E          0.013465
# H1         0.986535
# {'TGFb': 0, 'RAS': 1, 'Twist1': 0}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 16.220035791397095
#               Ratio
# phenotype
# E          0.013646
# H1         0.986354
# {'TGFb': 0, 'RAS': 1, 'ZEB1': 0}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 14.205076694488525
#            Ratio
# phenotype
# E            1.0
# {'TGFb': 0, 'RAS': 1, 'bcatenin': 0}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 14.055542230606079
#               Ratio
# phenotype
# E          0.729989
# H1         0.270011
# {'TGFb': 0, 'RAS': 1, 'miR200': 0}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 15.5314359664917
#               Ratio
# phenotype
# E          0.013771
# H1         0.986229
# {'TGFb': 0, 'RAS': 1, 'miR34': 0}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 15.087425231933594
#               Ratio
# phenotype
# E          0.013261
# H1         0.986739
# {'TGFb': 0, 'RAS': 1, 'p38': 0}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 15.226004600524902
#               Ratio
# phenotype
# E          0.013868
# H1         0.986132
# {'TGFb': 0, 'RAS': 1, 'p53': 0}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
# Attractor simulation time : 17.925710201263428
#               Ratio
# phenotype
# E          0.012197
# H1         0.987803

# %% [markdown]
# ### Molecular state ambiguity

# %%
from modules.frustration import computeFusingT_updated

fix_dict = {'TGFb':0,'RAS':1}
ctrl = {'TGFb':0,'RAS':1}
save_dir = './result/TGFOFF/' 
computeFusingT_updated(allsingles, fix_dict, ctrl, primes, model_file, save_dir+'TGFOFF_single')
